# %% [markdown]
# <a href="https://colab.research.google.com/github/Antoninus90/ActividadEDA_JavierFregoso/blob/main/Actividad%20individual.%20Estad%C3%ADstica%20Inferencial%3A%20del%20an%C3%A1lisis%20muestral%20a%20la%20predicci%C3%B3n%20poblacional.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

# %%
np.random.seed(42)

horas_sueno = np.random.normal(6.5, 1.2, 1000)

df1 = pd.DataFrame({
    "ID": range(1, 1001),
    "Horas_sueno": horas_sueno
})

df1.head()
# Out:
#    ID  Horas_sueno
# 0   1     7.096057
# 1   2     6.334083
# 2   3     7.277226
# 3   4     8.327636
# 4   5     6.219016

# %%
grupo1 = np.random.normal(8.5, 0.8, 500)
grupo2 = np.random.normal(7.8, 0.9, 500)

df2 = pd.DataFrame({
    "ID": range(1, 1001),
    "Grupo": ["Ejercicio"]*500 + ["No ejercicio"]*500,
    "Calificacion": np.concatenate([grupo1, grupo2])
})

df2.head()
# Out:
#    ID      Grupo  Calificacion
# 0   1  Ejercicio      9.619484
# 1   2  Ejercicio      9.239707
# 2   3  Ejercicio      8.547704
# 3   4  Ejercicio      7.982451
# 4   5  Ejercicio      9.058579

# %%
df1.describe()
# Out:
#                 ID  Horas_sueno
# count  1000.000000  1000.000000
# mean    500.500000     6.523198
# std     288.819436     1.175059
# min       1.000000     2.610479
# 25%     250.750000     5.722892
# 50%     500.500000     6.530361
# 75%     750.250000     7.277533
# max    1000.000000    11.123278

# %%
df2.groupby("Grupo").describe()
# Out:
#                  ID                                                           \
#               count   mean         std    min     25%    50%     75%     max
# Grupo
# Ejercicio     500.0  250.5  144.481833    1.0  125.75  250.5  375.25   500.0
# No ejercicio  500.0  750.5  144.481833  501.0  625.75  750.5  875.25  1000.0
#
#              Calificacion                                                    \
#                     count      mean       std       min       25%       50%
# Grupo
# Ejercicio           500.0  8.586788  0.808197  6.182996  8.018056  8.595845
# No ejercicio        500.0  7.829869  0.885660  5.153650  7.249257  7.791978
#
#
#                    75%        max
# Grupo
# Ejercicio     9.103791  10.581346
# No ejercicio  8.429792  10.673797

# %%
plt.hist(df1["Horas_sueno"], bins=30)
plt.title("Horas de sueño")
plt.xlabel("Horas")
plt.ylabel("Frecuencia")
plt.show()

# %%
plt.hist(grupo1, bins=30, alpha=0.5, label="Ejercicio")
plt.hist(grupo2, bins=30, alpha=0.5, label="No ejercicio")
plt.legend()
plt.title("Calificaciones")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
sns.boxplot(x='Grupo', y='Calificacion', data=df2)
plt.title('Distribución de Calificaciones por Grupo')
plt.xlabel('Grupo')
plt.ylabel('Calificación')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
t_stat, p_value = stats.ttest_1samp(df1["Horas_sueno"], 7)
print("p-valor:", p_value)
# Out:
# p-valor: 5.360304781405541e-35

# %%
t_stat, p_value = stats.ttest_ind(grupo1, grupo2)
print("p-valor:", p_value)
# Out:
# p-valor: 2.178380838242487e-41

# %%
df1.to_csv("caso1.csv", index=False)
df2.to_csv("caso2.csv", index=False)

# %%
t_stat, p_value = stats.ttest_1samp(df1["Horas_sueno"], 7)

print("Estadístico t:", t_stat)
print("p-valor:", p_value)
# Out:
# Estadístico t: -12.831514628126959
# p-valor: 5.360304781405541e-35

# %%
t_stat, p_value = stats.ttest_ind(grupo1, grupo2)

print("Estadístico t:", t_stat)
print("p-valor:", p_value)
# Out:
# Estadístico t: 14.116232665194545
# p-valor: 2.178380838242487e-41

# %%
df1.to_csv("caso1.csv", index=False)
df2.to_csv("caso2.csv", index=False)

# %%
t_stat, p_value = stats.ttest_1samp(df1["Horas_sueno"], 7)

print("Estadístico t:", t_stat)
print("p-valor:", p_value)
# Out:
# Estadístico t: -12.831514628126959
# p-valor: 5.360304781405541e-35

# %%
t_stat, p_value = stats.ttest_ind(grupo1, grupo2)

print("Estadístico t:", t_stat)
print("p-valor:", p_value)
# Out:
# Estadístico t: 14.116232665194545
# p-valor: 2.178380838242487e-41

# %%
t_stat, p_value = stats.ttest_1samp(df1["Horas_sueno"], 7)

print("t:", t_stat)
print("p:", p_value)
# Out:
# t: -12.831514628126959
# p: 5.360304781405541e-35

# %%
t_stat, p_value = stats.ttest_ind(grupo1, grupo2)

print("t:", t_stat)
print("p:", p_value)
# Out:
# t: 14.116232665194545
# p: 2.178380838242487e-41

# %%
# H0: μ = 7
# H1: μ ≠ 7
# α = 0.05

# %%
# H0: μ1 = μ2
# H1: μ1 ≠ μ2
# α = 0.05

# %%
t_stat, p_value = stats.ttest_1samp(df1["Horas_sueno"], 7)

print("Estadístico t:", t_stat)
print("p-valor:", p_value)
# Out:
# Estadístico t: -12.831514628126959
# p-valor: 5.360304781405541e-35

# %%
t_stat, p_value = stats.ttest_ind(grupo1, grupo2)

print("Estadístico t:", t_stat)
print("p-valor:", p_value)
# Out:
# Estadístico t: 14.116232665194545
# p-valor: 2.178380838242487e-41

# %%
# H0: μ = 7
# H1: μ ≠ 7
# α = 0.05

# %%
# H0: μ1 = μ2
# H1: μ1 ≠ μ2
# α = 0.05
